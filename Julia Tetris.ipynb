# %% [markdown]
# # [Julia Tetris](https://github.com/djsegal/Tetris.jl)
#
# <span class="js-load-message cs-loading">This should only take a minute.</span>

# %%
cur_script = """
    <style class="js-load-remove-tag">
        .cs-loading:after {
            overflow: hidden;
            display: inline-block;
            vertical-align: bottom;
            -webkit-animation: cs-ellipsis steps(3,end) 3250ms infinite;      
            animation: cs-ellipsis steps(3,end) 3250ms infinite;
            content: "\\2026";
            width: 0px;
        }
        @keyframes cs-ellipsis { to { width: 0.9em; } }
        @-webkit-keyframes cs-ellipsis { to { width: 0.9em; } }
    </style>

    <script class="js-load-remove-tag">
      \$(".js-load-remove-tag").parent(".output_subarea").css("padding", "0");
    </script>
"""

display(HTML(cur_script))

using Suppressor

@suppress using Tetris
Tetris.setup()

cur_script = """
    <script class="js-load-remove-tag">
        \$(".js-load-message").remove();
        \$("#appmode-busy").css("opacity","0");
        \$('pre:contains("WebIO: setting up")').parent(".output_subarea").remove();
        \$(".js-load-remove-tag").parent(".output_subarea").remove();
    </script>
"""

display(HTML(cur_script))

# %% [markdown]
# ------
#
# ### Controls are:
#
# <div style="display: flex; margin-top: 8px;">
#     <table style="margin: auto;">
#         <thead>
#             <tr>
#                 <th style="text-align: center; line-height: 1.5;"> key </th>
#                 <th style="text-align: center; line-height: 1.5;"> action </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> &nbsp;&nbsp;⬅️&nbsp;&nbsp; </td>
#                 <td style="text-align: center; line-height: 2.0;"> slide left </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> ➡️ </td>
#                 <td style="text-align: center; line-height: 2.0;"> slide right </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> ⬆️ </td>
#                 <td style="text-align: center; line-height: 2.0;"> rotate right </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> ⬇️ </td>
#                 <td style="text-align: center; line-height: 2.0;"> soft drop </td>
#             </tr>
#         </tbody>
#     </table>
#     <table style="margin: auto;">
#         <thead>
#             <tr>
#                 <th style="text-align: center; line-height: 1.5;"> key </th>
#                 <th style="text-align: center; line-height: 1.5;"> action </th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> <code>M</code> </td>
#                 <td style="text-align: center; line-height: 2.0;"> play music </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> <code>C</code> </td>
#                 <td style="text-align: center; line-height: 2.0;"> hold piece </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> <code>Z</code> </td>
#                 <td style="text-align: center; line-height: 2.0;"> rotate left </td>
#             </tr>
#             <tr>
#                 <td style="text-align: center; line-height: 2.0;"> <code>SPACE</code> </td>
#                 <td style="text-align: center; line-height: 2.0;"> hard drop </td>
#             </tr>
#         </tbody>
#     </table>
# </div>
